# %% [markdown]
# # Exercicío 1

# %% [markdown]
# # Exercicío 2

# %% [markdown]
# ## exemplo na Seçao 8.1 na referência [29].

# %%
from plotnine import *
import seaborn as sea
import pandas as pd

# %% [markdown]
# ## exemplo explorado na Seção 3.5.3.

# %%
diamonds = sea.load_dataset('diamonds')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
ideal = diamonds[diamonds['cut'] == 'Ideal']
ideal
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z
# 0       0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 11      0.23  Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 13      0.31  Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 16      0.30  Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 39      0.33  Ideal     I     SI2   61.8   55.0    403  4.49  4.51  2.78
# ...      ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53925   0.79  Ideal     I     SI1   61.6   56.0   2756  5.95  5.97  3.67
# 53926   0.71  Ideal     E     SI1   61.9   56.0   2756  5.71  5.73  3.54
# 53929   0.71  Ideal     G     VS1   61.4   56.0   2756  5.76  5.73  3.53
# 53935   0.72  Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53939   0.75  Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [21551 rows x 10 columns]

# %%
premium = diamonds[diamonds['cut'] == 'Premium']
premium
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 14      0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15      0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53928   0.79  Premium     E     SI2   61.4   58.0   2756  6.03  5.96  3.68
# 53930   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
# [13791 rows x 10 columns]

# %%
algebra = diamonds[['carat', 'cut', 'price']]
algebra
# Out:
#        carat        cut  price
# 0       0.23      Ideal    326
# 1       0.21    Premium    326
# 2       0.23       Good    327
# 3       0.29    Premium    334
# 4       0.31       Good    335
# ...      ...        ...    ...
# 53935   0.72      Ideal   2757
# 53936   0.72       Good   2757
# 53937   0.70  Very Good   2757
# 53938   0.86    Premium   2757
# 53939   0.75      Ideal   2757
#
# [53940 rows x 3 columns]

# %%
ggplot(data = algebra) + geom_point(mapping = aes(x=algebra['price'],y=algebra['carat'], color = algebra['cut']))
# Out:
# <Figure Size: (640 x 480)>

# %%
ggplot (data = algebra) + geom_point (mapping = aes(x=algebra['price'],y=algebra['carat'], color = algebra['cut'])) + scale_x_continuous (breaks = range(2500,17500,2500)) + scale_y_continuous (breaks = [x / 10.0 for x in range(5, 50, 15)])
# Out:
# <Figure Size: (640 x 480)>

# %%
print('u_carat =', algebra['carat'].mean())
print('sd_carat =', algebra['carat'].std())
print('Md_carat =', algebra['carat'].median())

print('u_price = U$', algebra['price'].mean())
print('sd_price = U$', algebra['price'].std())
print('Md_price = u$', algebra['price'].median())
# Out:
# u_carat = 0.7979397478680014
# sd_carat = 0.4740112444054184
# Md_carat = 0.7
# u_price = U$ 3932.799721913237
# sd_price = U$ 3989.439738146379
# Md_price = u$ 2401.0

# %%
ggplot (data = algebra) + geom_histogram (mapping = aes(x=algebra['price'], color = algebra['cut']), binwidth=2000)
# Out:
# <Figure Size: (640 x 480)>

# %%
ggplot (data = algebra) + geom_freqpoly (mapping = aes(x=algebra['price'], color = algebra['cut']), binwidth=2000)
# Out:
# <Figure Size: (640 x 480)>

# %%
ggplot (data = algebra) + geom_histogram (mapping = aes(x=algebra['price'], color = algebra['cut']), binwidth=2000) + coord_flip ()
# Out:
# <Figure Size: (640 x 480)>

# %%
ggplot (data = algebra) + geom_histogram (mapping = aes(x=algebra['price'], color = algebra['cut']), binwidth=2000)
# + coord_polar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-7355c869388c> in <cell line: 1>()
# ----> 1 ggplot (data = algebra) + geom_histogram (mapping = aes(x=algebra['price'], color = algebra['cut']), binwidth=2000)  + coord_polar()
#
# NameError: name 'coord_polar' is not defined

# %%
ggplot (data = algebra, mapping = aes(x=algebra['price'],y=algebra['carat'], color = algebra['cut'])) + geom_point (mapping = aes()) + geom_smooth(method = "lm", se = False, color = 'blue')
# Out:
# <Figure Size: (640 x 480)>

# %%
ggplot (data = algebra, mapping = aes(x=algebra['price'],y=algebra['carat'], color = algebra['cut'])) + geom_point () + facet_wrap ('~cut', nrow=2)
# Out:
# <Figure Size: (640 x 480)>
